# %%
import pandas as pd
import gmplot
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from scipy.stats import norm
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import KFold   #For K-fold cross validation
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor


df = pd.read_csv("housing.csv")
df.head(10)
# Out:
# D:\anacoda\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# D:\anacoda\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# ...

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df['total_bedrooms'].fillna(df['total_bedrooms'].mean(),inplace = True)

# %%
df.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069260 -0.066658           -0.318998     0.927253
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069260    0.099773    0.055310      -0.015176
# latitude                 -0.066658   -0.108785   -0.071035      -0.079809
# ...

# %%
corr_matrix = df.corr()

# %%
corr_matrix['median_house_value'].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.688075
# total_rooms           0.134153
# housing_median_age    0.105623
# households            0.065843
# total_bedrooms        0.049454
# population           -0.024650
# longitude            -0.045967
# latitude             -0.144160
# Name: median_house_value, dtype: float64

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20640.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        419.266592   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# We can see total bedrooms has a very low correlation with median income so we just impute the mean to fill nas

# %%
df['total_bedrooms'].fillna(df['total_bedrooms'].mean,inplace = True)

# %%
latitudes = df["latitude"]
longitudes = df["longitude"]

# %%
gmap = gmplot.GoogleMapPlotter(37.88, -122.23, 10)
gmap.heatmap(latitudes, longitudes)

# %%
gmap.draw("my_heatmap.html")

# %%
df.hist(bins=100, figsize=(20,20) , color = 'b')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DA07FCF1D0>,
# ...
#       dtype=object)

# %%
plt.figure(figsize=(10,10))
plt.subplots_adjust(hspace = .25)
plt.subplot(1,1,1)
plt.xlabel('ocean_proximity',fontsize=12)
plt.ylabel('median_house_value',fontsize=12)
sns.boxplot(data=df,x='ocean_proximity',y='median_house_value')

plt.plot()
# Out:
# []

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10,6))
sns.distplot(df['median_house_value'],color='blue')
plt.show()
# Out:
# D:\anacoda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# We can see the distribution of our target variable to right skewed and not normal

# %%
ax = sns.distplot(df['median_house_value'], rug=True, hist=False)
# Out:
# D:\anacoda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
ax = sns.distplot(df['median_house_value'], fit=norm, kde=False)
# Out:
# D:\anacoda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [raw]
# Here we can see what the Hernel density estimation would look like on a normal distribution of data

# %%
ax = sns.scatterplot(x="longitude", y="latitude",hue="median_house_value",data=df)

# %%
df.plot(kind='scatter', x='longitude', y='latitude', alpha=0.9, 
    s=df['population']/10, label='population', figsize=(14,10), 
    c='median_house_value', cmap=plt.get_cmap('cool'), colorbar=True)

# %%
df.groupby(["ocean_proximity"])["median_house_value"].mean()
# Out:
# ocean_proximity
# <1H OCEAN     240084.285464
# INLAND        124805.392001
# ISLAND        380440.000000
# NEAR BAY      259212.311790
# NEAR OCEAN    249433.977427
# Name: median_house_value, dtype: float64

# %%
temp2 = df.pivot_table(values='median_house_value',index=['ocean_proximity'])
print(temp2)
# Out:
#                  median_house_value
# ocean_proximity
# <1H OCEAN             240084.285464
# INLAND                124805.392001
# ISLAND                380440.000000
# NEAR BAY              259212.311790
# NEAR OCEAN            249433.977427

# %%
temp2.plot(kind = 'bar')

# %% [markdown]
# we can see from the groups and data inland houses seem to have a much lover mean and medium house value suggesting the closer to the coast a block of houses are the higher the medium value and islands seem to contain outlier values, ocean proximity could possibly be a useful feature in predicting the house value

# %%
len(df)
# Out:
# 20640

# %%
df = df[df["ocean_proximity"] != "ISLAND"]

# %%
len(df)
# Out:
# 20635

# %%
df.plot(kind='scatter', x='median_income', y='median_house_value', alpha=0.2, figsize=(10,10))

# %% [markdown]
# here we see serval large horixonal lines in the scatter the largest of which is 500000 we will remove rows with 500000 to balalance the distribution a bit

# %%
#df = df[df["median_house_value"] < 499000]
#this was removed after observing the models accuracy rose when these values were left in it

# %%
len(df)
# Out:
# 20635

# %%
df.plot(kind='scatter', x='median_income', y='median_house_value', alpha=0.2, figsize=(10,10))

# %% [markdown]
# Since there is opnly 5 island districts and they are large outlier value we will remove islands from the dataset

# %%
df['rooms_per_household'] = df['total_rooms']/df['households']
df['bedrooms_per_room'] = df['total_bedrooms']/df['total_rooms']
df['people_per_house'] = df['population'] / df['households']

# %%
#Lets look at the correlation matrix again after munging the data
plt.figure(figsize=(12,7))
sns.heatmap(cbar=False,annot=True,data=df.corr()*100,cmap='Greens')
plt.title('% Corelation Matrix')
plt.show()

# %% [raw]
# some interesting data created bedroom per room having the third best corrolation but interesting people per house had a positive inpact in our models

# %% [markdown]
# removed the major outlier from before

# %%
le = LabelEncoder()
df["ocean_proximity"] = le.fit_transform(df["ocean_proximity"])
df.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0                2
# 1      2401.0      1138.0         8.3014            358500.0                2
# 2       496.0       177.0         7.2574            352100.0                2
# 3       558.0       219.0         5.6431            341300.0                2
# 4       565.0       259.0         3.8462            342200.0                2
#
#    rooms_per_household  bedrooms_per_room  people_per_house
# ...

# %% [markdown]
# encode ocean proximity to 0,1,2,3

# %%
#Generic function for making a classification model and accessing performance:
def regression_model(model, data, predictors, outcome):

  scaler = StandardScaler()
    
  model.fit(data[predictors],data[outcome])
  predictions = model.predict(data[predictors])
  #scale values to better fit model
  x = scaler.fit_transform(data[predictors].values)
  y = data[outcome].values
    
    
  mean_squared_errors = cross_val_score(model, x, y, n_jobs=-1, cv=10, scoring='neg_mean_squared_error')
  print ("Mean Squared Error: ", np.mean(mean_squared_errors))
  print("Root Mean Squared Error:", np.sqrt(np.absolute(np.mean(mean_squared_errors))))
    
  r_squared_value = cross_val_score(model, x, y, n_jobs=-1, cv=10, scoring='r2')
  print ("R2 Score: ", np.mean(r_squared_value))
    


  kf = KFold(data.shape[0], n_folds=10)
  error = []
  for train, test in kf:
    train_predictors = x[train]
    train_target = y[train]
    
    model.fit(train_predictors, train_target)
    error.append(model.score(x[test], y[test]))
 
  print ("Cross-Validation Score : %s" % "{0:.3%}".format(np.mean(error)))

  #Fit the model again so that it can be refered outside the function:
  model.fit(data[predictors],data[outcome])

# %%
outcome_var = 'median_house_value'
predictor_var = ['ocean_proximity','rooms_per_household','median_income']
model = LinearRegression()
regression_model(model, df,predictor_var,outcome_var)
# Out:
# Mean Squared Error:  -7379595312.5045805
# Root Mean Squared Error: 85904.5709639748
# R2 Score:  0.33771399132225965
# Cross-Validation Score : 33.771%

# %%
pred = ['ocean_proximity','people_per_house','median_income', 'housing_median_age', 'rooms_per_household',
              'longitude']
model = LinearRegression()
regression_model(model, df, pred,"median_house_value")
# Out:
# Mean Squared Error:  -6971286156.261708
# Root Mean Squared Error: 83494.22828113155
# R2 Score:  0.3716988562855713
# Cross-Validation Score : 37.170%

# %%
predictor_var = ['ocean_proximity','rooms_per_household','median_income']
model = DecisionTreeRegressor(random_state=0)
regression_model(model, df, pred,"median_house_value")
# Out:
# Mean Squared Error:  -7568969371.933111
# Root Mean Squared Error: 86999.823976449
# R2 Score:  0.2875534345217155
# Cross-Validation Score : 28.755%

# %%
list(df)
# Out:
# ['longitude',
#  'latitude',
#  'housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'median_house_value',
#  'ocean_proximity',
#  'rooms_per_household',
#  'bedrooms_per_room',
#  'people_per_house']

# %%
pred = ['ocean_proximity','people_per_house','median_income', 'housing_median_age', 'rooms_per_household',
              'longitude','bedrooms_per_room']
model = DecisionTreeRegressor(random_state=0)
regression_model(model, df, pred,"median_house_value")
# Out:
# Mean Squared Error:  -7476537263.415256
# Root Mean Squared Error: 86466.97209579653
# R2 Score:  0.3000265876864342
# Cross-Validation Score : 30.003%

# %%
pred = ['ocean_proximity','people_per_house','median_income', 'housing_median_age', 'rooms_per_household',
              'longitude']
model = RandomForestRegressor(n_estimators=50,random_state=0)
regression_model(model, df, pred,"median_house_value")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0757a35e49a0> in <module>()
#       1 pred = ['ocean_proximity','people_per_house','median_income', 'housing_median_age', 'rooms_per_household',
#       2               'longitude']
# ----> 3 model = RandomForestRegressor(n_estimators=50,random_state=0)
#       4 regression_model(model, df, pred,"median_house_value")
#
# NameError: name 'RandomForestRegressor' is not defined

# %%
pred = ['ocean_proximity','people_per_house','median_income', 'housing_median_age', 'rooms_per_household',
              'longitude','bedrooms_per_room']
model = RandomForestRegressor(n_estimators=50,random_state=0)
regression_model(model, df, pred,"median_house_value")
# Out:
# Mean Squared Error:  -4156318850.0046754
# Root Mean Squared Error: 64469.51876665961
# R2 Score:  0.6176489373753513
# Cross-Validation Score : 61.765%

# %% [markdown]
# The strongest performing model was the random forest model with the highest cross validation score,
# The models as a whole didnt perform that well i dont believe this is a problem with the models but rather the dataset's features did not give enough data to accuarte predict the mediam house value

# %%
outcome = 'median_house_value'
predictors = ['ocean_proximity','people_per_house','median_income', 'housing_median_age', 'rooms_per_household',
              'longitude' ]
model = RandomForestRegressor(n_estimators=50,random_state=0)


x = df[predictors]
y = df[outcome]

mean_squared_errors = cross_val_score(model, x, y, n_jobs=-1, cv=10, scoring='neg_mean_squared_error')
print ("Mean Squared Error: ", np.mean(mean_squared_errors))
print("Root Mean Squared Error:", np.sqrt(np.absolute(np.mean(mean_squared_errors))))
    
r_squared_value = cross_val_score(model, x, y, n_jobs=-1, cv=10, scoring='r2')
print ("R2 Score: ", np.mean(r_squared_value))
# Out:
# Mean Squared Error:  -4238501179.204075
# Root Mean Squared Error: 65103.77238842673
# R2 Score:  0.6098669883219696

# %% [markdown]
# The values are scaled in our regression model but as you can see it dint make much difference to performance
